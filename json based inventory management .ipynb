# %%
stuff={101:{"name":"chocolates",    "price":"20",     "quantity":"50",   "discount":"2",     "expirydate":"22-10-2022"},                
102:{"name": "drinks",              "price":"48",       "quantity":"25",      "discount":"10",     "expirydate":"02-01-2023"},
103:{"name": "Cake",                "price":"40",      "quantity":"75",      "discount":"12",     "expirydate":"25-04-2022"},
104:{"name": "Bread",                "price":"30",      "quantity":"15",      "discount":"1",     "expirydate":"18-11-2021"}, 
105:{"name": "Belgian Waffle",       "price":"50",      "quantity":"18",      "discount":"0",     "expirydate":"28-12-2023"},
106:{"name": "Waffle Cone Premix",   "price":"48",      "quantity":"25",      "discount":"2",     "expirydate":"22-10-2022"},
107:{"name": "Pastry",               "price":"45",       "quantity":"40",      "discount":"8",     "expirydate":"29-06-2021"},
108:{"name": "Ice Cream ",            "price":"15",      "quantity":"65",      "discount":"13",     "expirydate":"27-08-2022"},
109:{"name": "Muffins",               "price":"60",      "quantity":"90",      "discount":"2",     "expirydate":"23-01-2021"},
110:{"name": "biscuits",              "price":"28",      "quantity":"125",      "discount":"7",     "expirydate":"10--2022"},
111:{"name": "choco chips",            "price":"29",      "quantity":"55",      "discount":"6",     "expirydate":"18-08-2023"},
112:{"name": "Buns",                   "price":"13",      "quantity":"25",      "discount":"0",     "expirydate":"02-09-2024"}, 
113:{"name": "dark fudge",             "price":"38",      "quantity":"75",      "discount":"2",     "expirydate":"19-04-2022"},
114:{"name": " pizza",               "price":"165",      "quantity":"55",      "discount":"12",     "expirydate":"26-05-2023"},
115:{"name": " loaf breads",         "price":"18",      "quantity":"35",      "discount":"0",     "expirydate":"16-17-2025"},
116:{"name": "sweet rolls",          "price":"58",      "quantity":"75",      "discount":"0",     "expirydate":"26-08-2023"},
117:{"name": "cinnamon rolls ",     "price":"75",      "quantity":"45",      "discount":"9",     "expirydate":"29-12-2021"},
118:{"name": "Doughnuts",           "price":"80",      "quantity":"22",      "discount":"8",     "expirydate":"05-10-2020"},
119:{"name": "Pies",                "price":"38",      "quantity":"51",      "discount":"5",     "expirydate":"24-02-2022"}, 
120:{"name": "chewing gums",        "price":"15",      "quantity":"32",      "discount":"0",     "expirydate":"22-02-2022"},
121:{"name": "whipping cream",      "price":"105",      "quantity":"24",      "discount":"10",     "expirydate":"15-07-2023"},
122:{"name":"toffees",              "price":"90",      "quantity":"34",      "discount":"0",     "expirydate":"22-10-2022"},
123:{"name": "peanut butter",       "price":"110",      "quantity":"19",      "discount":"0",     "expirydate":"16-04-2022"},
124:{"name": "candies",             "price":"48",      "quantity":"125",      "discount":"4",     "expirydate":"25-11-2023"},
125:{"name": "milkshake",           "price":"20",      "quantity":"14",      "discount":"2",     "expirydate":"23-05-2024"},
126:{"name": "rusk toast",          "price":"30",      "quantity":"23",      "discount":"6",     "expirydate":"06-03-2021"}, 
127:{"name": "caramel",             "price":"35",      "quantity":"52",      "discount":"0",     "expirydate":"15-10-2022"},
128:{"name": "butter milk",         "price":"27",      "quantity":"20",      "discount":"1",     "expirydate":"29-06-2022"},
129:{"name": "pastry",             "price":"55",      "quantity":"85",      "discount":"6",     "expirydate":"14-10-2022"},
130:{"name": "ice gola",           "price":"44",      "quantity":"25",      "discount":"0",     "expirydate":"11-01-2021"}}

# %%
stuff
# Out:
# {101: {'name': 'chocolates',
#   'price': '20',
#   'quantity': '50',
#   'discount': '2',
#   'expirydate': '22-10-2022'},
#  102: {'name': 'drinks',
#   'price': '48',
#   'quantity': '25',
#   'discount': '10',
#   'expirydate': '02-01-2023'},
#  103: {'name': 'Cake',
#   'price': '40',
#   'quantity': '75',
#   'discount': '12',
#   'expirydate': '25-04-2022'},
#  104: {'name': 'Bread',
#   'price': '30',
#   'quantity': '15',
#   'discount': '1',
#   'expirydate': '18-11-2021'},
#  105: {'name': 'Belgian Waffle',
#   'price': '50',
#   'quantity': '18',
#   'discount': '0',
#   'expirydate': '28-12-2023'},
#  106: {'name': 'Waffle Cone Premix',
#   'price': '48',
#   'quantity': '25',
#   'discount': '2',
#   'expirydate': '22-10-2022'},
#  107: {'name': 'Pastry',
#   'price': '45',
#   'quantity': '40',
#   'discount': '8',
#   'expirydate': '29-06-2021'},
#  108: {'name': 'Ice Cream ',
#   'price': '15',
#   'quantity': '65',
#   'discount': '13',
# ...

# %%
import json

# %%
js=json.dumps(stuff)

# %%
js
# Out:
# '{"101": {"name": "chocolates", "price": "20", "quantity": "50", "discount": "2", "expirydate": "22-10-2022"}, "102": {"name": "drinks", "price": "48", "quantity": "25", "discount": "10", "expirydate": "02-01-2023"}, "103": {"name": "Cake", "price": "40", "quantity": "75", "discount": "12", "expirydate": "25-04-2022"}, "104": {"name": "Bread", "price": "30", "quantity": "15", "discount": "1", "expirydate": "18-11-2021"}, "105": {"name": "Belgian Waffle", "price": "50", "quantity": "18", "discount": "0", "expirydate": "28-12-2023"}, "106": {"name": "Waffle Cone Premix", "price": "48", "quantity": "25", "discount": "2", "expirydate": "22-10-2022"}, "107": {"name": "Pastry", "price": "45", "quantity": "40", "discount": "8", "expirydate": "29-06-2021"}, "108": {"name": "Ice Cream ", "price": "15", "quantity": "65", "discount": "13", "expirydate": "27-08-2022"}, "109": {"name": "Muffins", "price": "60", "quantity": "90", "discount": "2", "expirydate": "23-01-2021"}, "110": {"name": "biscu
# ...

# %%
stuff
# Out:
# {101: {'name': 'chocolates',
#   'price': '20',
#   'quantity': '50',
#   'discount': '2',
#   'expirydate': '22-10-2022'},
#  102: {'name': 'drinks',
#   'price': '48',
#   'quantity': '25',
#   'discount': '10',
#   'expirydate': '02-01-2023'},
#  103: {'name': 'Cake',
#   'price': '40',
#   'quantity': '75',
#   'discount': '12',
#   'expirydate': '25-04-2022'},
#  104: {'name': 'Bread',
#   'price': '30',
#   'quantity': '15',
#   'discount': '1',
#   'expirydate': '18-11-2021'},
#  105: {'name': 'Belgian Waffle',
#   'price': '50',
#   'quantity': '18',
#   'discount': '0',
#   'expirydate': '28-12-2023'},
#  106: {'name': 'Waffle Cone Premix',
#   'price': '48',
#   'quantity': '25',
#   'discount': '2',
#   'expirydate': '22-10-2022'},
#  107: {'name': 'Pastry',
#   'price': '45',
#   'quantity': '40',
#   'discount': '8',
#   'expirydate': '29-06-2021'},
#  108: {'name': 'Ice Cream ',
#   'price': '15',
#   'quantity': '65',
#   'discount': '13',
# ...

# %%
type(js)
# Out:
# str

# %%
type(stuff)
# Out:
# dict

# %%
fd=open("stuff.json",'w')
fd.write(js)
fd.close()

# %%
fd=open("stuff.json",'r')
txt=fd.read()
fd.close()

# %%
txt
# Out:
# '{"101": {"name": "chocolates", "price": "20", "quantity": "50", "discount": "2", "expirydate": "22-10-2022"}, "102": {"name": "drinks", "price": "48", "quantity": "25", "discount": "10", "expirydate": "02-01-2023"}, "103": {"name": "Cake", "price": "40", "quantity": "75", "discount": "12", "expirydate": "25-04-2022"}, "104": {"name": "Bread", "price": "30", "quantity": "15", "discount": "1", "expirydate": "18-11-2021"}, "105": {"name": "Belgian Waffle", "price": "50", "quantity": "18", "discount": "0", "expirydate": "28-12-2023"}, "106": {"name": "Waffle Cone Premix", "price": "48", "quantity": "25", "discount": "2", "expirydate": "22-10-2022"}, "107": {"name": "Pastry", "price": "45", "quantity": "40", "discount": "8", "expirydate": "29-06-2021"}, "108": {"name": "Ice Cream ", "price": "15", "quantity": "65", "discount": "13", "expirydate": "27-08-2022"}, "109": {"name": "Muffins", "price": "60", "quantity": "90", "discount": "2", "expirydate": "23-01-2021"}, "110": {"name": "biscu
# ...

# %%
stuff=json.loads(txt)

# %%
stuff
# Out:
# {'101': {'name': 'chocolates',
#   'price': '20',
#   'quantity': '50',
#   'discount': '2',
#   'expirydate': '22-10-2022'},
#  '102': {'name': 'drinks',
#   'price': '48',
#   'quantity': '25',
#   'discount': '10',
#   'expirydate': '02-01-2023'},
#  '103': {'name': 'Cake',
#   'price': '40',
#   'quantity': '75',
#   'discount': '12',
#   'expirydate': '25-04-2022'},
#  '104': {'name': 'Bread',
#   'price': '30',
#   'quantity': '15',
#   'discount': '1',
#   'expirydate': '18-11-2021'},
#  '105': {'name': 'Belgian Waffle',
#   'price': '50',
#   'quantity': '18',
#   'discount': '0',
#   'expirydate': '28-12-2023'},
#  '106': {'name': 'Waffle Cone Premix',
#   'price': '48',
#   'quantity': '25',
#   'discount': '2',
#   'expirydate': '22-10-2022'},
#  '107': {'name': 'Pastry',
#   'price': '45',
#   'quantity': '40',
#   'discount': '8',
#   'expirydate': '29-06-2021'},
#  '108': {'name': 'Ice Cream ',
#   'price': '15',
#   'quantity': '65',
#   'discount': '13',
# ...
